# %% [markdown]
# ## #1 什么是Makefile
# 1. 一个企业级项目，通常会有很多源文件，有时也会按功能、类型、模块分门别类的放在不同的目录中，有时候也会在一个目录里存放了多个程序的源代码。这时，如何对这些代码的编译就成了个问题。Makefle就是为这个问题而生的，它定义了一套规则，决定了哪些文件要先编译，哪些文件后编译，哪些文件要重新编译。
#
# 2. 整个工程通常只要一个make命令就可以完成编译、链接，甚至更复杂的功能。可以说，任何一个Linux源程序都带有一个Makefile文件。如果能掌握Makefile文件的编写方法，就能脱离可视化编译器，使用编译链工具编译出所需的目标文件。

# %% [markdown]
# ## #2 Makefile的优点
#
# 1. 管理代码的编译，决定该编译什么文件，编译顺序，以及是否需要重新编译；
#
# 2. 节省编译时间。如果文件有更改，只需重新编译此文件即可，无需重新编译整个工程；
#
# 3. 一劳永逸。Makefile通常只需编写一次，后期就不用过多更改。

# %% [markdown]
# ## #3 Makefile的编写规则
# ![image.png](attachment:cdb62c17-fe2c-44bd-b7f5-96b35a3f5df4.png)!![image.png](attachment:3b83aed9-4d1e-4604-a8f3-b7ca523b1138.png)

# %% [markdown]
# ## #4 创建工程目录
# ![image.png](attachment:4f29f821-ca82-4723-80f8-b1b8f39bbd60.png)

# %% [markdown]
# ## #5 编写makefile内容
# ![image.png](attachment:1feb044f-28c9-4068-a035-9189ceced5a5.png)

# %% [markdown]
# ## #6 makefile的工作原理
# ![image.png](attachment:0f15f373-f7ad-4c74-b6dd-2d46cd23d2bf.png)

# %% [markdown]
# ## #7 进入工程目录makefile_tutorial当中执行make命令: 使用此命令即可按预定的规则生成目标文件
# ![image.png](attachment:932dc06b-7539-4e5f-900b-ce9d979782ff.png)

# %% [markdown]
# ## #8 运行程序
# ![image.png](attachment:2893cafc-731c-4cd1-9602-d3d809fdb432.png)

# %% [markdown]
# ## #9 Makefile的变量使用
# #### 其实，我们可以像 C 一样，用一个符号来代替一个字符串内容
# ![image.png](attachment:c29cd05c-dc62-4fe6-a5a7-848451e6a293.png)
# #### 上面的例子中，我们用 OBJ 来代替了 main.o add.o sub.o mul.o div.o 这一长串文件。注意的是，在引用变量时，需要用 $() 来包括住变量。

# %% [markdown]
# ## #10 清空编译文件
# 我们发现每次编译的过程中都会产生一大堆中间文件，这令人感到杂乱，每个 Makefile 中都应该写一个清空目标文件（.o和执行文件）的规则，这不仅便于重编译，也很利于保持文件的清洁。
# ![image.png](attachment:178c23a6-a97c-4af1-8351-449f85be44ba.png)
# .PHONY 意思表示 clean 是一个“伪目标”，在rm命令前面加了一个小减号的意思就是，也许某些文件出现问题，但不要管，继续做后面的事。clean 的规则不要放在文件的开头，不然，这就会变成make 的默认目标，一般我们都会放在文件结尾处。
#
# ### 输入命令行：make clean 就可以清除对应的文件了。
# ![image.png](attachment:64622668-5fb6-4cfd-9671-4d3d7ba1579a.png)
